# %% [markdown]
# <div align="center" style="font-size: 2rem">
#
# <img heoght="300px" src="https://cta-observatory.github.io/ctapipe/_images/ctapipe_logo.png" alt="ctapipe"/>
#
#
# <p style="text-align: center;">LST Analysis Bootcamp</p>
#
# <p style="text-align: center">Padova, 26.11.2018</p>
#
# <p style="text-align: center">Maximilian Nöthe (@maxnoe) & Kai A. Brügge (@mackaiver)</p>
#
# </div>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 14

plt.rcParams['figure.figsize']
# Out:
# [12.0, 8.0]

# %%
# %%javascript
# $.getScript('https://kmahelona.github.io/ipython_notebook_goodies/ipython_notebook_toc.js')

# %% [markdown]
# <h1 id="tocheading">Table of Contents</h1>
# <div id="toc"></div>

# %% [markdown]
# # General Information

# %% [markdown]
# ## Design
#
# * DL0 → DL3 analysis
#
# * Currently some R0 → DL0 code to be able to analyze simtel files
#
# * ctapipe is built upon the Scientific Python Stack, core dependencies are
#   * numpy
#   * scipy
#   * astropy

# %% [markdown]
# ## Developement
#
# * ctapipe is developed as Open Source Software (Currently under MIT License) at <https://github.com/cta-observatory/ctapipe>
#
# * We use the "Github-Workflow":
#   * Few people (e.g. @kosack, @mackaiver) have write access to the main repository
#   * Contributors fork the main repository and work on branches
#   * Pull Requests are merged after Code Review and automatic execution of the test suite
#
# * Early developement stage ⇒ backwards-incompatible API changes might and will happen
#
# * Many open design questions ⇒ Core Developer Meeting in the second week of December in Dortmund

# %% [markdown]
# ## What's there?
#
# * Reading simtel simulation files
# * Simple calibration, cleaning and feature extraction functions
# * Camera and Array plotting
# * Coordinate frames and transformations
# * Stereo-reconstruction using line intersections

# %% [markdown]
# ## What's still missing?
#
# * Easy to use IO of analysis results to standard data formats (e.g. FITS, hdf5)
# * Easy to use "analysis builder"
# * A "Standard Analysis"
# * Good integration with machine learning techniques
# * IRF calculation
# * Defining APIs for IO, instrument description access etc.
# * Most code only tested on HESSIO simulations
# * Documentation, e.g. formal definitions of coordinate frames

# %% [markdown]
# ## What can you do?
#
# * Report issues
#   * Hard to get started? Tell us where you are stuck
#   * Tell user stories
#   * Missing features
#
# * Start contributing
#   * ctapipe needs more workpower
#   * Implement new reconstruction features

# %% [markdown]
# # A simple hillas analysis

# %% [markdown]
# ## Reading in simtel files

# %%
from ctapipe.io import EventSourceFactory ##figures out the correct file type we want to open
from ctapipe.utils.datasets import get_dataset_path

input_url = get_dataset_path('gamma_test_large.simtel.gz')

# The EventSourceFactory automatically detects what kind of file we are giving it,
# if already supported by ctapipe
event_source = EventSourceFactory.produce(input_url=input_url, max_events=9)

print(type(event_source))
# Out:
# <class 'ctapipe.io.hessioeventsource.HESSIOEventSource'>

# %%
for event in event_source:
    print('Id: {}, E = {:1.3f}, Telescopes: {}'.format(event.count, event.mc.energy, len(event.r0.tel)))
    ##checnk how many telescopes are at R0 level
# Out:
# Id: 0, E = 0.571 TeV, Telescopes: 4
# Id: 1, E = 1.864 TeV, Telescopes: 9
# Id: 2, E = 1.864 TeV, Telescopes: 4
# Id: 3, E = 1.864 TeV, Telescopes: 17
# Id: 4, E = 1.864 TeV, Telescopes: 2
# Id: 5, E = 0.464 TeV, Telescopes: 7
# Id: 6, E = 0.017 TeV, Telescopes: 2
# Id: 7, E = 76.426 TeV, Telescopes: 4
# Id: 8, E = 76.426 TeV, Telescopes: 16

# %% [markdown]
# Each event is a `DataContainer` holding several `Field`s of data, which can be containers or just numbers.
# Let's look a one event:

# %%
event
# Out:
# ctapipe.io.containers.DataContainer:
#                           r0.*: Raw Data
#                           r1.*: R1 Calibrated Data
#                          dl0.*: DL0 Data Volume Reduced Data
#                          dl1.*: DL1 Calibrated image
#                          dl2.*: Reconstructed Shower Information
#                           mc.*: Monte-Carlo data
#                     mcheader.*: Monte-Carlo run header data
#                         trig.*: central trigger information
#                          count: number of events processed
#                         inst.*: instrumental information (deprecated
#                    pointing[*]: Telescope pointing positions

# %%
event.inst.subarray.camera_types
# Out:
# ['FlashCam', 'ASTRICam', 'LSTCam']

# %%
len(event.r0.tel), len(event.r1.tel)
# Out:
# (16, 0)

# %% [markdown]
# ## Data calibration
#
# As we saw, the data container only contains raw data (only the `r0` containers are filled)
#
# So we use the `CameraCalibrator` factory to calibrate the event.

# %%
from ctapipe.calib import CameraCalibrator

calibrator = CameraCalibrator(
    eventsource=event_source,
)

# %%
calibrator.r1

# %%
calibrator.calibrate(event)

# %% [markdown]
# ## Event displays
#
# Let's use ctapipe's plotting facilities to plot the telescope images

# %%
event.dl1.tel.keys()
# Out:
# dict_keys([32, 33, 65, 35, 41, 10, 45, 15, 17, 18, 22, 23, 57, 27, 29, 31])

# %%
tel_id = 15

# %%
camera = event.inst.subarray.tel[tel_id].camera
dl1 = event.dl1.tel[tel_id]

camera, dl1
# Out:
# (CameraGeometry(cam_id='FlashCam', pix_type='hexagonal', npix=1764, cam_rot=0.0 deg, pix_rot=30.0 deg),
#  ctapipe.io.containers.DL1CameraContainer:
#                           image: np array of camera image, after waveform
#                                  integration (N_pix)
#                    gain_channel: boolean numpy array of which gain channel was
#                                  used for each pixel in the image
#               extracted_samples: numpy array of bools indicating which samples
#                                  were included in the charge extraction as a
#                                  result of the charge extractor chosen.
#                                  Shape=(nchan, npix, nsamples).
#                         peakpos: numpy array containing position of the peak as
#                                  determined by the peak-finding algorithm for
#                                  each pixel
#                         cleaned: numpy array containing the waveform after
#                                  cleaning)

# %%
from ctapipe.visualization import CameraDisplay

display = CameraDisplay(camera)

# right now, there might be one image per gain channel.
# This will change as soon as 
display.image = dl1.image[0] 
display.add_colorbar()

# %% [markdown]
# ## Image Cleaning

# %%
from ctapipe.image.cleaning import tailcuts_clean

# %%
# unoptimized cleaning levels, copied from 
# https://github.com/tudo-astroparticlephysics/cta_preprocessing
cleaning_level = {
    'ASTRICam': (5, 7, 2),  # (5, 10)?
    'LSTCam': (3.5, 7.5, 2),  # ?? (3, 6) for Abelardo...
    'FlashCam': (4, 8, 2),  # there is some scaling missing?
}

# %%
boundary, picture, min_neighbors = cleaning_level[camera.cam_id]

clean = tailcuts_clean(
    camera, 
    dl1.image[0],
    boundary_thresh=boundary,
    picture_thresh=picture,
    min_number_picture_neighbors=min_neighbors
)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

d1 = CameraDisplay(camera, ax=ax1) #image info
d2 = CameraDisplay(camera, ax=ax2) #time info

ax1.set_title('Image')
d1.image = dl1.image[0]
d1.add_colorbar(ax=ax1)

ax2.set_title('PeakPos')
d2.image = dl1.peakpos[0] - np.average(dl1.peakpos[0], weights=dl1.image[0]) #time info where 0 is the shower center
d2.cmap = 'RdBu_r'
d2.add_colorbar(ax=ax2)

d1.highlight_pixels(clean, color='red', linewidth=1)

# %% [markdown]
# ## Image Parameters

# %%
from ctapipe.image import hillas_parameters, leakage, concentration
#leakage : how well contained is the shower (counts active pixels at the camera border)
from ctapipe.image.timing_parameters import timing_parameters
from ctapipe.image.cleaning import number_of_islands

# %%
hillas = hillas_parameters(camera[clean], dl1.image[0][clean])
#phi polar coord of center of gravity
#psi is the orientation
#r and skewness are important for monoanalysis
print(hillas)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-daf04a8e3ac1> in <module>()
# ----> 1 hillas = hillas_parameters(camera[clean], dl1.image[0][clean])
#       2
#       3 print(hillas)
#
# NameError: name 'camera' is not defined

# %%
display = CameraDisplay(camera)

# set "unclean" pixels to 0
cleaned = dl1.image[0].copy()
cleaned[~clean] = 0.0

display.image = cleaned
display.add_colorbar()

display.overlay_moments(hillas, color='xkcd:red')

# %%
timing = timing_parameters(
    camera[clean],
    dl1.image[0][clean],
    dl1.peakpos[0][clean],
    hillas,
)
#linear regression of arrival times
print(timing)
# Out:
# {'intercept': 12.28501706134627, 'slope': <Quantity -7.59392097 1 / m>}

# %%
long, trans = camera.get_shower_coordinates(hillas.x, hillas.y, hillas.psi)

plt.plot(long[clean], dl1.peakpos[0][clean], 'o')
plt.plot(long[clean], timing.slope * long[clean] + timing.intercept)

# %%
l = leakage(camera, dl1.image[0], clean)
print(l)
# Out:
# {'leakage1_intensity': 0.017067592570373782,
#  'leakage1_pixel': 0.01020408163265306,
#  'leakage2_intensity': 0.04572030062200985,
#  'leakage2_pixel': 0.023809523809523808}

# %%
disp = CameraDisplay(camera)
disp.image = dl1.image[0]
disp.highlight_pixels(camera.get_border_pixel_mask(2), linewidth=2, color='xkcd:red')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-ee7d62aed850> in <module>()
# ----> 1 disp = CameraDisplay(camera)
#       2 disp.image = dl1.image[0]
#       3 disp.highlight_pixels(camera.get_border_pixel_mask(2), linewidth=2, color='xkcd:red')
#
# NameError: name 'CameraDisplay' is not defined

# %%
n_islands, island_id = number_of_islands(camera, clean)

print(n_islands)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-f41e70207ddb> in <module>()
# ----> 1 n_islands, island_id = number_of_islands(camera, clean)
#       2
#       3 print(n_islands)
#
# NameError: name 'camera' is not defined

# %%
conc = concentration(camera, dl1.image[0], hillas)
print(conc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-dcc7f21e8d10> in <module>()
# ----> 1 conc = concentration(camera, dl1.image[0], hillas)
#       2 print(conc)
#
# NameError: name 'camera' is not defined

# %% [markdown]
# ## Putting it all together / Stereo reconstruction

# %%
import astropy.units as u

from ctapipe.io import EventSourceFactory
from ctapipe.utils.datasets import get_dataset_path

from ctapipe.calib import CameraCalibrator

from ctapipe.image.cleaning import tailcuts_clean, number_of_islands
from ctapipe.image import hillas_parameters, leakage, concentration
from ctapipe.image.timing_parameters import timing_parameters

from ctapipe.reco import HillasReconstructor

from ctapipe.io import HDF5TableWriter

from copy import deepcopy ##to plot a nice event display
import tempfile

# unoptimized cleaning levels, copied from 
# https://github.com/tudo-astroparticlephysics/cta_preprocessing
cleaning_level = {
    'ASTRICam': (5, 7, 2),  # (5, 10)?
    'LSTCam': (3.5, 7.5, 2),  # ?? (3, 6) for Abelardo...
    'FlashCam': (4, 8, 2),  # there is some scaling missing?
}


input_url = get_dataset_path('gamma_test_large.simtel.gz')
event_source = EventSourceFactory.produce(input_url=input_url)

calibrator = CameraCalibrator(
    eventsource=event_source,
)

reco = HillasReconstructor()

f = tempfile.NamedTemporaryFile(suffix='.hdf5')

with HDF5TableWriter(f.name, mode='w', group_name='events') as writer:
    
    for event in event_source:
        print('Id: {}, E = {:1.3f}, Telescopes: {}'.format(event.count, event.mc.energy, len(event.r0.tel)))
        
        calibrator.calibrate(event)

        # mapping of telescope_id to parameters for stereo reconstruction
        hillas_containers = {}
        pointing_azimuth = {}
        pointing_altitude = {}
        time_gradients = {}

        for telescope_id, dl1 in event.dl1.tel.items():
            camera = event.inst.subarray.tels[telescope_id].camera
            image = dl1.image[0]
            peakpos = dl1.peakpos[0]

            boundary, picture, min_neighbors = cleaning_level[camera.cam_id]

            clean = tailcuts_clean(
                camera, 
                image,
                boundary_thresh=boundary,
                picture_thresh=picture,
                min_number_picture_neighbors=min_neighbors
            )

            # require more than five pixels after cleaning in each telescope
            if clean.sum() < 5:
                continue ##ignore the event
                ##we should add bookeeping of the reasons why we discard an event

            hillas_c = hillas_parameters(camera[clean], image[clean])
            leakage_c = leakage(camera, image, clean)
            n_islands, island_ids = number_of_islands(camera, clean)

            # remove events with high leakage
            if leakage_c.leakage2_intensity > 0.2:
                continue # to eliminate corner events, if intensity at the corner is more then 20% we discard the event

            timing_c = timing_parameters(camera[clean], image[clean], peakpos[clean], hillas_c)

            hillas_containers[telescope_id] = hillas_c

            # ssts have no timing in prod3b, so we'll use the skewness
            time_gradients[telescope_id] = (
                timing_c.slope.value 
                if camera.cam_id != 'ASTRICam' 
                else hillas_c.skewness
            )
            
            # this makes sure, that we get an arrow in the array plow for each telescope
            # might have the wrong direction though
            if abs(time_gradients[telescope_id]) < 0.2:
                time_gradients[telescope_id] = 1.0

            pointing_azimuth[telescope_id] = event.mc.tel[telescope_id].azimuth_raw * u.rad
            pointing_altitude[telescope_id] = event.mc.tel[telescope_id].altitude_raw * u.rad

        if len(hillas_containers) > 1:
            stereo = reco.predict(
                hillas_containers, event.inst, pointing_altitude, pointing_azimuth
            )

            writer.write('reconstructed', stereo)
            writer.write('true', event.mc)
    
            print('  Alt: {:.2f}°'.format(stereo.alt.deg))
            print('  Az: {:.2f}°'.format(stereo.az.deg))
            print('  Hmax: {:.0f}'.format(stereo.h_max))
            print('  CoreX: {:.1f}'.format(stereo.core_x))
            print('  CoreY: {:.1f}'.format(stereo.core_y))
        
        # save a nice event for plotting later
        if event.count == 3:
            plotting_event = deepcopy(event)
            plotting_hillas = hillas_containers
            plotting_timing = time_gradients
            plotting_stereo = stereo
# Out:
# WARNING:ctapipe.io.hessioeventsource.HESSIOEventSource:Only one pyhessio event_source allowed at a time. Previous hessio file will be closed.
# Id: 0, E = 0.571 TeV, Telescopes: 4
#   Alt: 66.38°
#   Az: -7.85°
#   Hmax: 8989 m
#   CoreX: 114.8 m
#   CoreY: -414.8 m
# Id: 1, E = 1.864 TeV, Telescopes: 9
#   Alt: 68.26°
#   Az: -353.38°
#   Hmax: 6766 m
#   CoreX: -47.1 m
#   CoreY: -387.1 m
# Id: 2, E = 1.864 TeV, Telescopes: 4
#   Alt: 68.52°
#   Az: -354.25°
#   Hmax: 7122 m
#   CoreX: -411.4 m
#   CoreY: -553.7 m
# Id: 3, E = 1.864 TeV, Telescopes: 17
#   Alt: 68.49°
#   Az: -353.30°
#   Hmax: 6614 m
#   CoreX: 88.0 m
#   CoreY: 5.2 m
# Id: 4, E = 1.864 TeV, Telescopes: 2
#   Alt: 68.66°
#   Az: -353.31°
#   Hmax: 6310 m
#   CoreX: -1095.7 m
#   CoreY: 474.8 m
# Id: 5, E = 0.464 TeV, Telescopes: 7
#   Alt: 71.91°
#   Az: -1.05°
#   Hmax: 8688 m
#   CoreX: -66.8 m
#   CoreY: 290.3 m
# Id: 6, E = 0.017 TeV, Telescopes: 2
#   Alt: 70.47°
#   Az: -359.53°
#   Hmax: 10853 m
#   CoreX: -172.4 m
#   CoreY: -325.4 m
# Id: 7, E = 76.426 TeV, Telescopes: 4
#   Alt: 74.39°
#   Az: -354.33°
#   Hmax: 8632 m
#   CoreX: 62.6 m
#   CoreY: -1128.0 m
# Id: 8, E = 76.426 TeV, Telescopes: 16
#   Alt: 75.27°
#   Az: -353.90°
#   Hmax: 5794 m
#   CoreX: 136.4 m
#   CoreY: 448.1 m
# Id: 9, E = 76.426 TeV, Telescopes: 3
#   Alt: 74.68°
#   Az: -354.14°
#   Hmax: 6994 m
#   CoreX: 904.4 m
#   CoreY: -996.3 m
# Id: 10, E = 0.267 TeV, Telescopes: 5
# Id: 11, E = 0.010 TeV, Telescopes: 2
# Id: 12, E = 1.407 TeV, Telescopes: 3
# Id: 13, E = 1.407 TeV, Telescopes: 3
# Id: 14, E = 0.121 TeV, Telescopes: 10
#   Alt: 67.33°
#   Az: -0.54°
#   Hmax: 12916 m
#   CoreX: -194.1 m
#   CoreY: -103.0 m
# Id: 15, E = 0.032 TeV, Telescopes: 4
#   Alt: 71.90°
#   Az: -0.47°
#   Hmax: 7854 m
#   CoreX: 21.2 m
#   CoreY: 65.8 m
# Id: 16, E = 0.073 TeV, Telescopes: 2
# Id: 17, E = 0.129 TeV, Telescopes: 3
#   Alt: 70.31°
#   Az: -353.32°
#   Hmax: 6351 m
#   CoreX: 186.6 m
#   CoreY: -130.4 m
# Id: 18, E = 0.129 TeV, Telescopes: 2
# Id: 19, E = 10.220 TeV, Telescopes: 2
# Id: 20, E = 10.220 TeV, Telescopes: 4
# Id: 21, E = 10.220 TeV, Telescopes: 4
# Id: 22, E = 0.055 TeV, Telescopes: 2
#   Alt: 73.02°
#   Az: -1.71°
#   Hmax: 7433 m
#   CoreX: -335.2 m
#   CoreY: 6.9 m
# Id: 23, E = 0.100 TeV, Telescopes: 3
#   Alt: 68.87°
#   Az: -350.51°
#   Hmax: 7799 m
#   CoreX: -123.7 m
#   CoreY: -148.0 m
# Id: 24, E = 0.079 TeV, Telescopes: 5
#   Alt: 68.44°
#   Az: -353.39°
#   Hmax: 10449 m
#   CoreX: -89.3 m
#   CoreY: 96.1 m
# Id: 25, E = 0.127 TeV, Telescopes: 7
#   Alt: 70.02°
#   Az: -3.93°
#   Hmax: 9349 m
#   CoreX: 19.9 m
#   CoreY: -189.2 m
# Id: 26, E = 3.923 TeV, Telescopes: 4
#   Alt: 70.36°
#   Az: -345.41°
#   Hmax: 6009 m
#   CoreX: 372.9 m
#   CoreY: -193.6 m
# Id: 27, E = 3.923 TeV, Telescopes: 2
# Id: 28, E = 3.923 TeV, Telescopes: 4
# Id: 29, E = 0.147 TeV, Telescopes: 6
#   Alt: 70.09°
#   Az: -3.90°
#   Hmax: 4951 m
#   CoreX: 131.8 m
#   CoreY: 224.3 m
# Id: 30, E = 0.974 TeV, Telescopes: 6
#   Alt: 73.41°
#   Az: -5.79°
#   Hmax: 8473 m
#   CoreX: 460.8 m
#   CoreY: 328.1 m
# Id: 31, E = 0.974 TeV, Telescopes: 3
#   Alt: 73.11°
#   Az: -6.72°
#   Hmax: 7639 m
#   CoreX: -84.8 m
#   CoreY: 554.9 m
# Id: 32, E = 0.474 TeV, Telescopes: 4
#   Alt: 70.96°
#   Az: -6.65°
#   Hmax: 7147 m
#   CoreX: -177.0 m
#   CoreY: -382.8 m
# Id: 33, E = 0.474 TeV, Telescopes: 4
#   Alt: 69.87°
#   Az: -13.45°
#   Hmax: 7294 m
#   CoreX: 451.1 m
#   CoreY: -297.8 m
# Id: 34, E = 0.110 TeV, Telescopes: 2
#   Alt: 71.91°
#   Az: -358.11°
#   Hmax: 8843 m
#   CoreX: -221.9 m
#   CoreY: -7.7 m
# Id: 35, E = 0.103 TeV, Telescopes: 2
# Id: 36, E = 0.120 TeV, Telescopes: 4
#   Alt: 68.61°
#   Az: -8.65°
#   Hmax: 10790 m
#   CoreX: 118.9 m
#   CoreY: -206.3 m
# Id: 37, E = 0.078 TeV, Telescopes: 4
#   Alt: 68.55°
#   Az: -355.36°
#   Hmax: 8969 m
#   CoreX: -155.6 m
#   CoreY: -143.6 m
# Id: 38, E = 0.079 TeV, Telescopes: 2
# Id: 39, E = 0.592 TeV, Telescopes: 4
# Id: 40, E = 0.066 TeV, Telescopes: 6
#   Alt: 68.64°
#   Az: -6.72°
#   Hmax: 10554 m
#   CoreX: 40.5 m
#   CoreY: -50.8 m
# Id: 41, E = 0.126 TeV, Telescopes: 3
#   Alt: 70.55°
#   Az: -5.25°
#   Hmax: 7087 m
#   CoreX: -317.4 m
#   CoreY: -608.4 m
# Id: 42, E = 0.126 TeV, Telescopes: 2
#   Alt: 71.77°
#   Az: -354.68°
#   Hmax: 8117 m
#   CoreX: -53.4 m
#   CoreY: -406.1 m
# Id: 43, E = 0.129 TeV, Telescopes: 2
# Id: 44, E = 0.017 TeV, Telescopes: 3
# Id: 45, E = 0.053 TeV, Telescopes: 2
#   Alt: 70.77°
#   Az: -355.33°
#   Hmax: 10492 m
#   CoreX: 461.5 m
#   CoreY: -97.6 m
# Id: 46, E = 0.009 TeV, Telescopes: 2
# Id: 47, E = 0.248 TeV, Telescopes: 4
#   Alt: 71.94°
#   Az: -0.06°
#   Hmax: 10466 m
#   CoreX: 467.2 m
#   CoreY: 96.6 m
# Id: 48, E = 0.248 TeV, Telescopes: 11
#   Alt: 71.99°
#   Az: -359.96°
#   Hmax: 10185 m
#   CoreX: 7.8 m
#   CoreY: -146.8 m
# Id: 49, E = 0.248 TeV, Telescopes: 4
#   Alt: 72.31°
#   Az: -1.82°
#   Hmax: 8114 m
#   CoreX: -375.7 m
#   CoreY: 68.8 m
# Id: 50, E = 5.327 TeV, Telescopes: 2
#   Alt: 66.68°
#   Az: -350.00°
#   Hmax: 6863 m
#   CoreX: -1063.1 m
#   CoreY: 871.4 m
# Id: 51, E = 5.327 TeV, Telescopes: 18
#   Alt: 67.15°
#   Az: -351.27°
#   Hmax: 6471 m
#   CoreX: -239.0 m
#   CoreY: 95.3 m
# Id: 52, E = 5.327 TeV, Telescopes: 2
# Id: 53, E = 0.095 TeV, Telescopes: 2
# Id: 54, E = 0.937 TeV, Telescopes: 2
# Id: 55, E = 0.937 TeV, Telescopes: 2
#   Alt: 69.82°
#   Az: -6.77°
#   Hmax: 9272 m
#   CoreX: -650.0 m
#   CoreY: -704.9 m
# Id: 56, E = 0.937 TeV, Telescopes: 4
#   Alt: 69.70°
#   Az: -7.29°
#   Hmax: 9496 m
#   CoreX: -610.7 m
#   CoreY: 133.9 m
# Id: 57, E = 0.937 TeV, Telescopes: 2
#   Alt: 70.15°
#   Az: -6.80°
#   Hmax: 9146 m
#   CoreX: 414.7 m
#   CoreY: 866.7 m
# Id: 58, E = 0.161 TeV, Telescopes: 2
# Id: 59, E = 0.407 TeV, Telescopes: 14
#   Alt: 69.63°
#   Az: -8.14°
#   Hmax: 9563 m
#   CoreX: -77.0 m
#   CoreY: -89.8 m
# Id: 60, E = 0.037 TeV, Telescopes: 3
#   Alt: 67.95°
#   Az: -358.47°
#   Hmax: 13899 m
#   CoreX: -244.8 m
#   CoreY: 7.4 m
# Id: 61, E = 0.020 TeV, Telescopes: 4
#   Alt: 70.56°
#   Az: -0.91°
#   Hmax: 9120 m
#   CoreX: 6.1 m
#   CoreY: 115.9 m
# Id: 62, E = 2.364 TeV, Telescopes: 4
#   Alt: 65.93°
#   Az: -359.46°
#   Hmax: 7717 m
#   CoreX: 575.9 m
#   CoreY: 726.1 m
# Id: 63, E = 0.710 TeV, Telescopes: 8
#   Alt: 71.36°
#   Az: -349.99°
#   Hmax: 10044 m
#   CoreX: 322.2 m
#   CoreY: 213.7 m
# Id: 64, E = 0.710 TeV, Telescopes: 2
#   Alt: 71.12°
#   Az: -348.24°
#   Hmax: 10473 m
#   CoreX: 677.4 m
#   CoreY: -573.6 m
# Id: 65, E = 1.158 TeV, Telescopes: 2
# Id: 66, E = 0.055 TeV, Telescopes: 5
#   Alt: 70.01°
#   Az: -355.29°
#   Hmax: 8964 m
#   CoreX: -11.0 m
#   CoreY: 151.0 m
# Id: 67, E = 0.032 TeV, Telescopes: 2
# Id: 68, E = 0.232 TeV, Telescopes: 3
#   Alt: 68.54°
#   Az: -5.28°
#   Hmax: 9933 m
#   CoreX: 461.2 m
#   CoreY: -445.8 m
# Id: 69, E = 0.232 TeV, Telescopes: 2
# Id: 70, E = 22.299 TeV, Telescopes: 5
#   Alt: 66.51°
#   Az: -358.32°
#   Hmax: 7062 m
#   CoreX: 142.9 m
#   CoreY: -857.3 m
# Id: 71, E = 22.299 TeV, Telescopes: 12
#   Alt: 63.75°
#   Az: -356.21°
#   Hmax: 7910 m
#   CoreX: -174.2 m
#   CoreY: 272.7 m
# Id: 72, E = 0.118 TeV, Telescopes: 3
#   Alt: 67.25°
#   Az: -4.93°
#   Hmax: 9284 m
#   CoreX: 186.7 m
#   CoreY: 290.8 m
# Id: 73, E = 0.118 TeV, Telescopes: 3
#   Alt: 67.35°
#   Az: -4.97°
#   Hmax: 8878 m
#   CoreX: 205.6 m
#   CoreY: -187.7 m
# Id: 74, E = 0.118 TeV, Telescopes: 5
#   Alt: 66.96°
#   Az: -5.50°
#   Hmax: 9044 m
#   CoreX: -72.5 m
#   CoreY: -342.1 m
# Id: 75, E = 0.101 TeV, Telescopes: 2
# Id: 76, E = 0.065 TeV, Telescopes: 2
# Id: 77, E = 3.581 TeV, Telescopes: 2
#   Alt: 71.09°
#   Az: -350.98°
#   Hmax: 9056 m
#   CoreX: -378.2 m
#   CoreY: -1158.3 m
# Id: 78, E = 3.581 TeV, Telescopes: 5
#   Alt: 71.12°
#   Az: -350.72°
#   Hmax: 8176 m
#   CoreX: 188.9 m
#   CoreY: -667.7 m
# Id: 79, E = 0.768 TeV, Telescopes: 5
#   Alt: 73.35°
#   Az: -1.09°
#   Hmax: 8307 m
#   CoreX: -223.4 m
#   CoreY: 158.4 m
# Id: 80, E = 0.290 TeV, Telescopes: 2
# Id: 81, E = 0.060 TeV, Telescopes: 2
# Id: 82, E = 2.967 TeV, Telescopes: 2
# Id: 83, E = 2.967 TeV, Telescopes: 2
# Id: 84, E = 0.142 TeV, Telescopes: 4
#   Alt: 69.81°
#   Az: -358.00°
#   Hmax: 11404 m
#   CoreX: -76.3 m
#   CoreY: -332.1 m
# Id: 85, E = 0.142 TeV, Telescopes: 2
# Id: 86, E = 0.435 TeV, Telescopes: 2
# Id: 87, E = 0.435 TeV, Telescopes: 2
# Id: 88, E = 0.339 TeV, Telescopes: 4
# Id: 89, E = 1.851 TeV, Telescopes: 4
#   Alt: 70.20°
#   Az: -0.28°
#   Hmax: 7715 m
#   CoreX: -819.7 m
#   CoreY: 178.7 m
# Id: 90, E = 1.851 TeV, Telescopes: 6
#   Alt: 69.46°
#   Az: -2.50°
#   Hmax: 7769 m
#   CoreX: -711.4 m
#   CoreY: -245.4 m
# Id: 91, E = 0.189 TeV, Telescopes: 11
#   Alt: 70.62°
#   Az: -3.68°
#   Hmax: 8559 m
#   CoreX: -48.2 m
#   CoreY: -92.3 m
# Id: 92, E = 0.037 TeV, Telescopes: 3
# Id: 93, E = 1.620 TeV, Telescopes: 4
#   Alt: 69.33°
#   Az: -7.07°
#   Hmax: 7272 m
#   CoreX: -867.3 m
#   CoreY: -196.4 m
# Id: 94, E = 1.620 TeV, Telescopes: 2
#   Alt: 69.55°
#   Az: -7.83°
#   Hmax: 7547 m
#   CoreX: -308.8 m
#   CoreY: -1091.5 m
# Id: 95, E = 1.620 TeV, Telescopes: 3
#   Alt: 68.61°
#   Az: -7.34°
#   Hmax: 7955 m
#   CoreX: 648.5 m
#   CoreY: -497.5 m
# Id: 96, E = 1.620 TeV, Telescopes: 3
#   Alt: 69.25°
#   Az: -7.28°
#   Hmax: 8051 m
#   CoreX: 93.0 m
#   CoreY: 864.4 m
# Id: 97, E = 1.620 TeV, Telescopes: 7
#   Alt: 69.18°
#   Az: -5.86°
#   Hmax: 7800 m
#   CoreX: 312.6 m
#   CoreY: -571.1 m
# Id: 98, E = 0.112 TeV, Telescopes: 3
#   Alt: 70.63°
#   Az: -358.24°
#   Hmax: 9227 m
#   CoreX: -28.3 m
#   CoreY: -351.0 m
# Id: 99, E = 0.322 TeV, Telescopes: 2
#   Alt: 69.17°
#   Az: -0.78°
#   Hmax: 6950 m
#   CoreX: -569.3 m
#   CoreY: 23.2 m
# Id: 100, E = 0.322 TeV, Telescopes: 10
#   Alt: 69.42°
#   Az: -0.69°
#   Hmax: 7608 m
#   CoreX: -177.6 m
#   CoreY: -222.8 m
# Id: 101, E = 6.104 TeV, Telescopes: 4
# Id: 102, E = 0.245 TeV, Telescopes: 3
# Id: 103, E = 0.636 TeV, Telescopes: 2
# Id: 104, E = 0.636 TeV, Telescopes: 4
# Id: 105, E = 1.824 TeV, Telescopes: 6
#   Alt: 70.24°
#   Az: -0.78°
#   Hmax: 6841 m
#   CoreX: -613.8 m
#   CoreY: -412.7 m
# Id: 106, E = 1.824 TeV, Telescopes: 2
# Id: 107, E = 1.824 TeV, Telescopes: 3
#   Alt: 70.20°
#   Az: -0.71°
#   Hmax: 6690 m
#   CoreX: 823.6 m
#   CoreY: -128.9 m
# Id: 108, E = 0.538 TeV, Telescopes: 5
#   Alt: 70.41°
#   Az: -348.50°
#   Hmax: 6886 m
#   CoreX: -182.7 m
#   CoreY: 69.2 m
# Id: 109, E = 0.538 TeV, Telescopes: 2

# %%
from astropy.coordinates.angle_utilities import angular_separation
import pandas as pd

#these events are diffused monte carlo
#they can be read with pandas
df_rec = pd.read_hdf(f.name, key='events/reconstructed')
df_true = pd.read_hdf(f.name, key='events/true')


theta = angular_separation(
    df_rec.az.values * u.deg, df_rec.alt.values * u.deg,
    df_true.az.values * u.deg, df_true.alt.values * u.deg,
)

plt.hist(theta.to(u.deg).value**2, bins=25, range=[0, 0.3])
plt.xlabel(r'$\theta² / deg²$')
None

# %% [markdown]
# ## ArrayDisplay

# %%
from ctapipe.visualization import ArrayDisplay


angle_offset = plotting_event.mcheader.run_array_direction[0]


disp = ArrayDisplay(plotting_event.inst.subarray)

disp.set_vector_hillas(
    plotting_hillas,
    time_gradient=plotting_timing,
    angle_offset=angle_offset,
    length=500
)

plt.scatter(
    plotting_event.mc.core_x, plotting_event.mc.core_y,
    s=200, c='k', marker='x', label='True Impact',
)
plt.scatter(
    plotting_stereo.core_x, plotting_stereo.core_y,
    s=200, c='r', marker='x', label='Estimated Impact',
)

plt.legend()
plt.xlim(-400, 400)
plt.ylim(-400, 400)
# Out:
# (-400, 400)

# %% [markdown]
# # LST Mono with output
#
#
# * Let's use the `HDF5TableWriter` to save the dl2 data to an hdf5 file
# * This is not ideal yet and one of the major points to be discussed in two weeks

# %%
from ctapipe.io import HDF5TableWriter
from ctapipe.core.container import Container, Field

input_url = get_dataset_path('gamma_test_large.simtel.gz')

event_source = EventSourceFactory.produce(
    input_url=input_url,
    allowed_tels=[1, 2, 3, 4], # only use the first LST
)


calibrator = CameraCalibrator(
    eventsource=event_source,
)


class EventInfo(Container):
    event_id = Field('event_id')
    obs_id =  Field('obs_id')
    telescope_id = Field('telescope_id')
    


with HDF5TableWriter(filename='hillas.h5', group_name='dl2', mode='w') as writer:

    for event in event_source:
        print('Id: {}, E = {:1.3f}, Telescopes: {}'.format(event.count, event.mc.energy, len(event.r0.tel)))
    
        calibrator.calibrate(event)
    
        for telescope_id, dl1 in event.dl1.tel.items():      

            camera = event.inst.subarray.tels[telescope_id].camera
            image = dl1.image[0]
            peakpos = dl1.peakpos[0]

            boundary, picture, min_neighbors = cleaning_level[camera.cam_id]

            clean = tailcuts_clean(
                camera, 
                image,
                boundary_thresh=boundary,
                picture_thresh=picture,
                min_number_picture_neighbors=min_neighbors
            )
            
            if clean.sum() < 5:
                continue
            
            event_info = EventInfo(event_id=event.r0.event_id, obs_id=event.r0.obs_id, telescope_id=telescope_id)
            hillas_c = hillas_parameters(camera[clean], image[clean])
            leakage_c = leakage(camera, image, clean)
            timing_c = timing_parameters(camera[clean], image[clean], peakpos[clean], hillas_c)

            writer.write('events', [event_info, event.mc, hillas_c, leakage_c, timing_c])
# Out:
# WARNING:ctapipe.io.hessioeventsource.HESSIOEventSource:Only one pyhessio event_source allowed at a time. Previous hessio file will be closed.
# Id: 0, E = 1.864 TeV, Telescopes: 17
# Id: 1, E = 0.017 TeV, Telescopes: 2
# Id: 2, E = 0.010 TeV, Telescopes: 2
# Id: 3, E = 0.121 TeV, Telescopes: 10
# Id: 4, E = 0.032 TeV, Telescopes: 4
# Id: 5, E = 0.073 TeV, Telescopes: 2
# Id: 6, E = 0.129 TeV, Telescopes: 2
# Id: 7, E = 0.079 TeV, Telescopes: 5
# Id: 8, E = 0.127 TeV, Telescopes: 7
# Id: 9, E = 0.147 TeV, Telescopes: 6
# Id: 10, E = 0.103 TeV, Telescopes: 2
# Id: 11, E = 0.078 TeV, Telescopes: 4
# Id: 12, E = 0.592 TeV, Telescopes: 4
# Id: 13, E = 0.066 TeV, Telescopes: 6
# Id: 14, E = 0.017 TeV, Telescopes: 3
# Id: 15, E = 0.009 TeV, Telescopes: 2
# Id: 16, E = 0.248 TeV, Telescopes: 11
# Id: 17, E = 5.327 TeV, Telescopes: 18
# Id: 18, E = 0.407 TeV, Telescopes: 14
# Id: 19, E = 0.037 TeV, Telescopes: 3
# Id: 20, E = 0.020 TeV, Telescopes: 4
# Id: 21, E = 0.710 TeV, Telescopes: 8
# Id: 22, E = 0.055 TeV, Telescopes: 5
# Id: 23, E = 0.032 TeV, Telescopes: 2
# Id: 24, E = 0.118 TeV, Telescopes: 5
# Id: 25, E = 0.142 TeV, Telescopes: 4
# Id: 26, E = 0.189 TeV, Telescopes: 11
# Id: 27, E = 0.037 TeV, Telescopes: 3
# Id: 28, E = 0.112 TeV, Telescopes: 3
# Id: 29, E = 0.322 TeV, Telescopes: 10

# %%
import pandas as pd

df = pd.read_hdf('hillas.h5')
df.set_index(['obs_id', 'event_id', 'telescope_id'], inplace=True)
df.head()
# Out:
#                                     alt        az      core_x      core_y  \
# obs_id event_id telescope_id
# 7514   31012    2             68.478978  6.384091   51.675117   69.654037
#                 3             68.478978  6.384091   51.675117   69.654037
#        90914    2             70.676229  3.107417 -113.833435 -142.343872
#                 4             70.676229  3.107417 -113.833435 -142.343872
#        153614   1             68.949967  2.666187  -51.531204 -106.752579
#
#                                 energy   h_first_int     intensity  intercept  \
# obs_id event_id telescope_id
# 7514   31012    2             1.863750  18171.726562    509.060050  10.573200
#                 3             1.863750  18171.726562  12233.367488  11.992900
#        90914    2             0.016544  15776.052734     90.516744   8.925852
#                 4             0.016544  15776.052734    116.223120   8.493800
#        153614   1             0.010250  19824.572266     80.086866   8.430104
#
#                               kurtosis  leakage1_intensity    ...     \
# obs_id event_id telescope_id                                  ...
# 7514   31012    2             2.004383            0.638961    ...
#                 3             3.700173            0.090044    ...
#        90914    2             2.867470            0.000000    ...
#                 4             2.086657            0.000000    ...
#        153614   1             2.766870            0.000000    ...
#
#                                      phi         psi         r  \
# obs_id event_id telescope_id
# 7514   31012    2             156.877186 -118.962228  1.045567
#                 3             130.789016  102.748958  0.837903
#        90914    2              51.460565   62.135299  0.909792
#                 4              69.194528   82.347736  0.961931
#        153614   1             118.223830   73.286384  0.966727
#
#                               shower_primary_id  skewness     slope     width  \
# obs_id event_id telescope_id
# 7514   31012    2                             0 -0.214465  4.686891  0.044054
#                 3                             0 -1.001438 -2.276120  0.109634
#        90914    2                             0  0.409119  3.005405  0.018728
#                 4                             0  0.050001  3.180487  0.024432
#        153614   1                             0 -0.310947 -6.540284  0.020285
#
#                                      x       x_max         y
# obs_id event_id telescope_id
# 7514   31012    2            -0.961571  379.538452  0.410597
#                 3            -0.547381  379.538452  0.634393
#        90914    2             0.566849  184.545456  0.711620
#                 4             0.341674  184.545456  0.899205
#        153614   1            -0.457182  241.111115  0.851789
#
# [5 rows x 24 columns]

# %%
plt.scatter(np.log10(df.energy), np.log10(df.intensity))
plt.xlabel('log10(E / TeV)')
plt.ylabel('log10(intensity)')
None

# %% [markdown]
# # Isn't python slow?
#
# * Many of you might have heard: "Python is slow".
# * That's trueish.
# * All python objects are classes living on the heap, event integers.
# * Looping over lots of "primitives" is quite slow compared to other languages.
#
# ⇒ Vectorize as much as possible using numpy
# ⇒ Use existing interfaces to fast C / C++ / Fortran code
# ⇒ Optimize using cython or numba
#
# **But: "Premature Optimization is the root of all evil" — Donald Knuth**
#
# So profile to find exactly what is slow.
#
# ## Why use python then?
#
# * Python works very well as *glue* for libraries of all kinds of languages
# * Python has a rich ecosystem for data science, physics, algorithms, astronomy
#
# ## Example: Number of Islands
#
# Find all groups of pixels, that survived the cleaning

# %%
from ctapipe.image import toymodel
from ctapipe.instrument import CameraGeometry


camera = CameraGeometry.from_name('LSTCam') #this is MC LSTCam, working on real one

# %% [markdown]
# Let's create a toy images with several islands;

# %%
np.random.seed(42)

image = np.zeros(camera.n_pixels)


for i in range(9):
    
    model = toymodel.generate_2d_shower_model(
        centroid=np.random.uniform(-0.8, 0.8, 2),
        width=np.random.uniform(0.05, 0.075),
        length=np.random.uniform(0.1, 0.15),
        psi=np.random.uniform(0, 2 * np.pi) * u.rad,
    )

    new_image, sig, bg = toymodel.make_toymodel_shower_image(
        camera,
        model.pdf, 
        intensity=np.random.uniform(1000, 3000),
        nsb_level_pe=5
    )
    image += new_image

# %%
clean = tailcuts_clean(camera, image, picture_thresh=10, boundary_thresh=5, min_number_picture_neighbors=2)

# %%
plt.figure(figsize=(16,9))
plt.matshow(camera.neighbor_matrix)

# %%
disp = CameraDisplay(camera)
disp.image = image
disp.highlight_pixels(clean, color='xkcd:red', linewidth=1.5)
disp.add_colorbar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-b3234ba4d5e2> in <module>()
# ----> 1 disp = CameraDisplay(camera)
#       2 disp.image = image
#       3 disp.highlight_pixels(clean, color='xkcd:red', linewidth=1.5)
#       4 disp.add_colorbar()
#
# NameError: name 'CameraDisplay' is not defined

# %%
def num_islands_python(camera, clean):
    ''' A breadth first search to find connected islands of neighboring pixels in the cleaning set'''
    
    # the camera geometry has a [n_pixel, n_pixel] boolean array
    # that is True where two pixels are neighbors
    neighbors = camera.neighbor_matrix
    
    island_ids = np.zeros(camera.n_pixels)
    current_island = 0
    
    # a set to remember which pixels we already visited
    visited = set()

    # go only through the pixels, that survived cleaning
    for pix_id in np.where(clean)[0]:
        if pix_id not in visited:
            # remember that we already checked this pixel
            visited.add(pix_id)
            
            # if we land in the outer loop again, we found a new island
            current_island += 1
            island_ids[pix_id] = current_island
            
            # now check all neighbors of the current pixel recursively
            to_check = set(np.where(neighbors[pix_id] & clean)[0])
            while to_check:
                pix_id = to_check.pop()
                
                if pix_id not in visited:    
                    visited.add(pix_id)
                    island_ids[pix_id] = current_island
                    
                    to_check.update(np.where(neighbors[pix_id] & clean)[0])
    
    n_islands = current_island
    return n_islands, island_ids
#start from 1 pixel and find all connected pixels, then move to the next and so on... then we get the islands

# %%
n_islands, island_ids = num_islands_python(camera, clean)

# %%
from matplotlib.colors import ListedColormap

cmap = plt.get_cmap('Paired')
cmap = ListedColormap(cmap.colors[:n_islands])
cmap.set_under('k')

disp = CameraDisplay(camera)
disp.image = island_ids
disp.cmap = cmap
disp.set_limits_minmax(0.5, n_islands + 0.5)
disp.add_colorbar()

# %%
# %timeit num_islands_python(camera, clean)
# Out:
# 3.21 ms ± 233 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
from scipy.sparse.csgraph import connected_components

def num_islands_scipy(camera, clean):
    neighbors = camera.neighbor_matrix_sparse
    
    clean_neighbors = neighbors[clean][:, clean]
    num_islands, labels = connected_components(clean_neighbors, directed=False)
    
    island_ids = np.zeros(camera.n_pixels)
    island_ids[clean] = labels + 1
    
    return num_islands, island_ids

# %%
n_islands_s, island_ids_s = num_islands_scipy(camera, clean)

# %%
from ctapipe.visualization import CameraDisplay
disp = CameraDisplay(camera)
disp.image = island_ids_s
disp.cmap = cmap
disp.set_limits_minmax(0.5, n_islands_s + 0.5)
disp.add_colorbar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-c72968d38b65> in <module>()
#       2 disp = CameraDisplay(camera)
#       3 disp.image = island_ids_s
# ----> 4 disp.cmap = cmap
#       5 disp.set_limits_minmax(0.5, n_islands_s + 0.5)
#       6 disp.add_colorbar()
#
# NameError: name 'cmap' is not defined

# %%
# %timeit num_islands_scipy(camera, clean)
# Out:
# 1.13 ms ± 8.66 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# **A lot less code, and a factor 3 speed improvement**
